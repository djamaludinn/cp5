# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

response = requests.get('https://cdn.igromania.ru/mnt/news/3/2/8/9/d/d/101942/93b8b85acef24f13_1920xH.jpg')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
